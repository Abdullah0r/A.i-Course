# %% [markdown]
# # python string

# %%
# create a string using double quotes
string1 = "Python programming"

# create a string using single quotes
string1 = 'Python programming'

# %% [markdown]
# # indexing

# %%
greet = 'hello'
print(greet[1])
# Out:
# e

# %% [markdown]
# # negative indexing

# %%
student = 'ali'
print(student[-2])
# Out:
# l

# %% [markdown]
# # slicing

# %%
greet = 'Hello'

# access character from 1st index to 3rd index
print(greet[1:4])  # "ell"
# Out:
# ell

# %%
dic = {'name ':'Ali','city':'multan','institue':'corvit'}
print(dic)
dic ['country'] = 'pak'
print(dic)
print(dic['city'])
del dic ['institue']
print(dic)
# Out:
# {'name ': 'Ali', 'city': 'multan', 'institue': 'corvit'}
# {'name ': 'Ali', 'city': 'multan', 'institue': 'corvit', 'country': 'pak'}
# multan
# {'name ': 'Ali', 'city': 'multan', 'country': 'pak'}

# %%
number = {'ten:10','twenty:20','thirty:30' }
num ={'forty : 40','fifty:50','sixty:60'}
number.update(num)
print(number)
# Out:
# {'ten:10', 'sixty:60', 'twenty:20', 'thirty:30', 'fifty:50', 'forty : 40'}

# %%
string = 'navttc'
freq = {}
for i in string:
    if i in freq:
         freq[i] += 1
    else:
        freq [i] = 1
        
print(freq)
# Out:
# {'n': 1, 'a': 1, 'v': 1, 't': 2, 'c': 1}
