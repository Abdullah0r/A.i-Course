# %%
number = [i for i in  range(1,6)]
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
# even number

# %%
even = [i for i in range(1,20) if i % 2== 0]
print(even)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %% [markdown]
# # to find number even odd

# %%
result = ["even" if i % 2 == 0 else 'odd' for i in range(1,11)]
print(result
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even']

# %%
sq = [c * c for c in range (1,8)]
print(sq)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
a = {1,8,16}
newlist = {i*i for i in a}
print(newlist)
# Out:
# {64, 1, 256}
