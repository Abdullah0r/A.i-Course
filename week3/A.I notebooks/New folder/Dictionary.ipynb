# %% [markdown]
# # disctionary

# %%
first_last = {'hasan ': 'naser','ubaid':'riaz','ali':'ubaid'}
print(first_last)
# Out:
# {'hasan ': 'naser', 'ubaid': 'riaz', 'ali': 'ubaid'}

# %% [markdown]
# # access value of dictionary

# %%
first_last = {'hasan':'naser','ubaid':'riaz','ali':'ubaid'}
print(first_last)
print('value is = :',first_last['hasan'])
# Out:
# {'hasan': 'naser', 'ubaid': 'riaz', 'ali': 'ubaid'}
# value is = : naser

# %% [markdown]
# # add item in dict

# %%
first_last['kareem'] = 'zubair'
print(first_last)
# Out:
# {'hasan': 'naser', 'ubaid': 'riaz', 'ali': 'ubaid', 'kareem': 'zubair'}

# %% [markdown]
# # remove from dict

# %%
del first_last['ubaid']
print(first_last)
# Out:
# {'hasan': 'naser', 'ali': 'ubaid', 'kareem': 'zubair'}

# %% [markdown]
# # reverse list

# %%
a = [9,77,99,33,22,47]
reverse =[]
for i in range (len(a)-1,-1,-1):
      reverse.append(a[i])
print(reverse)
# Out:
# [47, 22, 33, 99, 77, 9]

# %% [markdown]
# # find avg of num

# %%
a = [23,45,78,90,123]
total = 0
for num in a:
    total += num
averg = total/len(a)
print('sum',total)
print(averg)
# Out:
# sum 359
# 71.8

# %%
cust_order = ['mango','orange','peach','lpj',lpj]
# seting unique
unique_item = set(cust_order)
order_count =[]
for item in cust_order:
    if item in order_Count
    order_count [item] += 1
