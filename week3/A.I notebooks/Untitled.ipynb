# %% [markdown]
# # set

# %%
student_id = (102,103,104,105)
print('student id is = :',student_id)
# Out:
# student id is = : (102, 103, 104, 105)

# %%
student_id = (102,103,104,105)
print('student id is = :',student_id)
for i in student_id:
      print(i)
# Out:
# student id is = : (102, 103, 104, 105)
# 102
# 103
# 104
# 105

# %% [markdown]
# # number add in set

# %%
set = {22,34,56,78}
print(set)
set.add(21)
print(set)
# Out:
# {56, 34, 78, 22}
# {34, 78, 21, 22, 56}

# %% [markdown]
# # update in set

# %%
firstset = {'ubaid','ramzan'}
sndset = {'r','s'}
firstset.update(sndset)
print(firstset)
# Out:
# {'s', 'ramzan', 'r', 'ubaid'}

# %% [markdown]
# # Remove an Element from a Set

# %%
company = {'apple','java','pip'}
print(company)
removedvalue = company.discard('pip')
print(company)
# Out:
# {'apple', 'pip', 'java'}
# {'apple', 'java'}
